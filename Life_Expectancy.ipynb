# %% [markdown]
# Import necessary libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Read the data into the notebook

# %%
data = pd.read_csv('train.csv')

# %% [markdown]
# Display information about the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               2350 non-null   object
#  1   Country                          2350 non-null   object
#  2   Year                             2350 non-null   int64
#  3   Status                           2350 non-null   object
#  4   Life_expectancy                  2350 non-null   float64
#  5   Adult_Mortality                  2342 non-null   float64
#  6   infant_deaths                    2350 non-null   int64
#  7   Alcohol                          2192 non-null   float64
#  8   percentage_expenditure           2350 non-null   float64
#  9   Hepatitis_B                      1911 non-null   float64
#  10  Measles                          2350 non-null   int64
#  11  BMI                              2323 non-null   float64
# ...

# %%
data.head()
# Out:
#            ID      Country  Year      Status  Life_expectancy  \
# 0  Af04604195  Afghanistan  2013  Developing             59.9
# 1  Af04794049  Afghanistan  2000  Developing             54.8
# 2  Af07527693  Afghanistan  2006  Developing             57.3
# 3  Af11267444  Afghanistan  2010  Developing             58.8
# 4  Af12688448  Afghanistan  2005  Developing             57.3
#
#    Adult_Mortality  infant_deaths  Alcohol  percentage_expenditure  \
# 0            268.0             66     0.01               73.219243
# 1            321.0             88     0.01               10.424960
# 2            295.0             84     0.03               17.171518
# 3            279.0             74     0.01               79.679367
# 4            291.0             85     0.02                1.388648
#
#    Hepatitis_B  ...  Polio  Total_expenditure  Diphtheria  HIV_AIDS  \
# 0         64.0  ...   62.0               8.13        64.0       0.1
# ...

# %%
data.shape
# Out:
# (2350, 23)

# %%
data.describe()
# Out:
#               Year  Life_expectancy  Adult_Mortality  infant_deaths  \
# count  2350.000000      2350.000000      2342.000000    2350.000000
# mean   2007.537447        69.275404       165.824082      28.793191
# std       4.611986         9.573065       125.273598     111.836006
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2004.000000        63.300000        74.000000       0.000000
# 50%    2008.000000        72.200000       144.000000       3.000000
# 75%    2012.000000        75.700000       227.750000      20.750000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            Alcohol  percentage_expenditure  Hepatitis_B        Measles  \
# count  2192.000000             2350.000000  1911.000000    2350.000000
# mean      4.593271              720.521353    81.141811    2318.703404
# std       4.034828             1952.616462    24.821252   11589.618520
# ...

# %% [markdown]
# Plot Distplots to view potential outliers

# %%
sns.jointplot(x = 'Adult_Mortality', y = 'Life_expectancy', data = data)

# %%
sns.jointplot(x = 'infant_deaths', y = 'Life_expectancy', data = data)

# %%
sns.jointplot(x = 'percentage_expenditure', y = 'Life_expectancy', data = data)

# %%
sns.jointplot(x = 'Hepatitis_B', y = 'Life_expectancy', data = data)

# %%
sns.jointplot(x = 'Measles', y = 'Life_expectancy', data = data)

# %%
sns.jointplot(x = 'under_five_deaths', y = 'Life_expectancy', data = data)

# %%
sns.jointplot(x = 'Polio', y = 'Life_expectancy', data = data)

# %%
sns.jointplot(x = 'Diphtheria', y = 'Life_expectancy', data = data)

# %%
sns.jointplot(x = 'HIV_AIDS', y = 'Life_expectancy', data = data)

# %%
sns.jointplot(x = 'GDP', y = 'Life_expectancy', data = data)

# %%
sns.jointplot(x = 'Population', y = 'Life_expectancy', data = data)

# %%
sns.jointplot(x = 'thinness_1-19_years', y = 'Life_expectancy', data = data)

# %%
sns.jointplot(x = 'thinness_5-9_years', y = 'Life_expectancy', data = data)

# %% [markdown]
# Filling in the missing values

# %%
data.Alcohol = data.Alcohol.fillna(data.Alcohol.mean())
data.Hepatitis_B = data.Hepatitis_B.fillna(data.Hepatitis_B.mean())
data.BMI = data.BMI.fillna(data.BMI.mean())
data.Polio = data.Polio.fillna(data.Polio.mean())
data.Total_expenditure = data.Total_expenditure.fillna(data.Total_expenditure.mean())
data.Diphtheria = data.Diphtheria.fillna(data.Diphtheria.mean())
data.HIV_AIDS = data.HIV_AIDS.fillna(data.HIV_AIDS.mean())
data.GDP = data.GDP.fillna(data.GDP.mean())
data.Population = data.Population.fillna(data.Population.mean())
data.Income_composition_of_resources = data.Income_composition_of_resources.fillna(data.Income_composition_of_resources.mean())
data.Schooling = data.Schooling.fillna(data.Schooling.mean())
data.Adult_Mortality = data.Adult_Mortality.fillna(data.Adult_Mortality.mean())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               2350 non-null   object
#  1   Country                          2350 non-null   object
#  2   Year                             2350 non-null   int64
#  3   Status                           2350 non-null   object
#  4   Life_expectancy                  2350 non-null   float64
#  5   Adult_Mortality                  2350 non-null   float64
#  6   infant_deaths                    2350 non-null   int64
#  7   Alcohol                          2350 non-null   float64
#  8   percentage_expenditure           2350 non-null   float64
#  9   Hepatitis_B                      2350 non-null   float64
#  10  Measles                          2350 non-null   int64
#  11  BMI                              2350 non-null   float64
# ...

# %%
data.describe()
# Out:
#               Year  Life_expectancy  Adult_Mortality  infant_deaths  \
# count  2350.000000      2350.000000      2350.000000    2350.000000
# mean   2007.537447        69.275404       165.824082      28.793191
# std       4.611986         9.573065       125.060094     111.836006
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2004.000000        63.300000        74.000000       0.000000
# 50%    2008.000000        72.200000       144.000000       3.000000
# 75%    2012.000000        75.700000       227.000000      20.750000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            Alcohol  percentage_expenditure  Hepatitis_B        Measles  \
# count  2350.000000             2350.000000  2350.000000    2350.000000
# mean      4.593271              720.521353    81.141811    2318.703404
# std       3.896770             1952.616462    22.381998   11589.618520
# ...

# %% [markdown]
# Solving Outliers

# %%
np.percentile(data.Measles, [99])[0]
# Out:
# 52546.16999999996

# %%
me = np.percentile(data.Measles, [99])[0]

# %%
data[(data.Measles > me)]
# Out:
#               ID                           Country  Year      Status  \
# 330   Bu80402418                      Burkina Faso  2009  Developing
# 399   Ch03368309                             China  2006  Developing
# 423   Ch70252032                             China  2005  Developing
# 426   Ch76061229                             China  2001  Developing
# 429   Ch87885277                             China  2000  Developing
# 430   Ch96320320                             China  2004  Developing
# 431   Ch96539779                             China  2014  Developing
# 555   De09220922  Democratic Republic of the Congo  2011  Developing
# 567   De41483114  Democratic Republic of the Congo  2013  Developing
# 571   De48336133  Democratic Republic of the Congo  2006  Developing
# 581   De69987959  Democratic Republic of the Congo  2005  Developing
# 587   De84295160  Democratic Republic of the Congo  2012  Developing
# 942   In04324722                             India  2004  Developing
# ...

# %%
data.Measles[(data.Measles >0.6 *me)] = 0.6*me
# Out:
# /var/folders/qs/qdbfrx3j5vg02bq77wgvz3f80000gn/T/ipykernel_3932/3801006505.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data.Measles[(data.Measles >0.6 *me)] = 0.6*me
# ...

# %%
data.Measles.describe()
# Out:
# count     2350.000000
# mean      1579.726290
# std       5172.399161
# min          0.000000
# 25%          0.000000
# 50%         16.000000
# 75%        356.250000
# max      31527.702000
# Name: Measles, dtype: float64

# %%
np.percentile(data.GDP, [99])[0]
# Out:
# 62337.13820199996

# %%
gdp = np.percentile(data.GDP, [99])[0]

# %%
data[(data.GDP > gdp * 1)]
# Out:
#               ID      Country  Year      Status  Life_expectancy  \
# 107   Au63114483    Australia  2012   Developed             82.3
# 116   Au99198627    Australia  2013   Developed             82.5
# 553   De04061937      Denmark  2014   Developed             84.0
# 554   De08100673      Denmark  2008   Developed             78.8
# 926   Ic07919742      Iceland  2007   Developed             81.3
# 1218  Lu43947910   Luxembourg  2004   Developed             78.7
# 1219  Lu64825564   Luxembourg  2008   Developed             80.0
# 1222  Lu77336160   Luxembourg  2013   Developed             81.4
# 1223  Lu83817666   Luxembourg  2011   Developed             88.0
# 1518  No07320260       Norway  2006   Developed             84.0
# 1519  No33466994       Norway  2010   Developed             81.0
# 1525  No80361192       Norway  2007   Developed             85.0
# 1655  Qa35779046        Qatar  2012  Developing             77.8
# ...

# %%
data.GDP.describe()
# Out:
# count      2350.000000
# mean       7384.623471
# std       13106.537701
# min           1.681350
# 25%         564.088121
# 50%        3054.363603
# 75%        7384.623471
# max      115761.577000
# Name: GDP, dtype: float64

# %%
data.GDP[(data.GDP >1 *gdp)] = 1*gdp
# Out:
# /var/folders/qs/qdbfrx3j5vg02bq77wgvz3f80000gn/T/ipykernel_3932/3593902258.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data.GDP[(data.GDP >1 *gdp)] = 1*gdp
# ...

# %%
np.percentile(data.Population, [99])[0]
# Out:
# 143672105.92999992

# %%
pop = np.percentile(data.Population, [99])[0]

# %%
data[(data.Population > pop)]
# Out:
#               ID             Country  Year      Status  Life_expectancy  \
# 141   Ba16646492          Bangladesh  2007  Developing             68.6
# 283   Br13548255              Brazil  2003  Developing             71.8
# 285   Br18179864              Brazil  2010  Developing             73.8
# 290   Br53046548              Brazil  2005  Developing             72.7
# 292   Br55951172              Brazil  2011  Developing             74.1
# 298   Br77659666              Brazil  2004  Developing             72.0
# 941   In03679611           Indonesia  2014  Developing             68.9
# 942   In04324722               India  2004  Developing             64.0
# 943   In08614344           Indonesia  2008  Developing             67.7
# 945   In18506711           Indonesia  2007  Developing             67.5
# 949   In33429688           Indonesia  2015  Developing             69.1
# 954   In46387437               India  2014  Developing             68.0
# ...

# %%
data.Population[(data.Population > 1 *pop)] = 1*pop
# Out:
# /var/folders/qs/qdbfrx3j5vg02bq77wgvz3f80000gn/T/ipykernel_3932/4079200523.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data.Population[(data.Population > 1 *pop)] = 1*pop
# ...

# %%
data.Population.describe()
# Out:
# count    2.350000e+03
# mean     1.017001e+07
# std      2.043004e+07
# min      3.400000e+01
# 25%      3.949550e+05
# 50%      3.746860e+06
# 75%      1.192254e+07
# max      1.436721e+08
# Name: Population, dtype: float64

# %%
sns.jointplot(x = 'Population', y = 'Life_expectancy', data = data)

# %%
data.under_five_deaths.describe()
# Out:
# count    2350.000000
# mean       40.094468
# std       152.939537
# min         0.000000
# 25%         0.000000
# 50%         4.000000
# 75%        26.000000
# max      2500.000000
# Name: under_five_deaths, dtype: float64

# %%
np.percentile(data.under_five_deaths, [99])[0]
# Out:
# 753.1199999999972

# %%
ufd = np.percentile(data.under_five_deaths, [99])[0]

# %%
data[(data.under_five_deaths > ufd)]
# Out:
#               ID  Country  Year      Status  Life_expectancy  Adult_Mortality  \
# 942   In04324722    India  2004  Developing             64.0            214.0
# 944   In09816447    India  2011  Developing             66.8            193.0
# 946   In23258207    India  2002  Developing             63.3            219.0
# 947   In29166267    India  2000  Developing             62.5            224.0
# 948   In29844654    India  2010  Developing             66.4            196.0
# 950   In38201863    India  2003  Developing             63.7            216.0
# 952   In43970523    India  2015  Developing             68.3            181.0
# 954   In46387437    India  2014  Developing             68.0            184.0
# 955   In54901558    India  2013  Developing             67.6            187.0
# 956   In66506394    India  2007  Developing             65.2             26.0
# 959   In77099325    India  2012  Developing             67.3             19.0
# ...

# %%
data.under_five_deaths[(data.under_five_deaths > 1 *ufd)] = 1*ufd
# Out:
# /var/folders/qs/qdbfrx3j5vg02bq77wgvz3f80000gn/T/ipykernel_3932/3148184605.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data.under_five_deaths[(data.under_five_deaths > 1 *ufd)] = 1*ufd
# ...

# %%
data.under_five_deaths.describe()
# Out:
# count    2350.000000
# mean       34.471438
# std        96.237490
# min         0.000000
# 25%         0.000000
# 50%         4.000000
# 75%        26.000000
# max       753.120000
# Name: under_five_deaths, dtype: float64

# %%
data.percentage_expenditure.describe()
# Out:
# count     2350.000000
# mean       720.521353
# std       1952.616462
# min          0.000000
# 25%          5.491010
# 50%         65.611455
# 75%        441.534144
# max      19099.045060
# Name: percentage_expenditure, dtype: float64

# %%
np.percentile(data.percentage_expenditure, [99])[0]
# Out:
# 10256.542402799998

# %%
pe = np.percentile(data.percentage_expenditure, [99])[0]

# %%
data[(data.percentage_expenditure > pe)]
# Out:
#               ID      Country  Year     Status  Life_expectancy  \
# 102   Au43901571    Australia  2014  Developed             82.7
# 107   Au63114483    Australia  2012  Developed             82.3
# 109   Au69167834    Australia  2011  Developed             82.0
# 116   Au99198627    Australia  2013  Developed             82.5
# 553   De04061937      Denmark  2014  Developed             84.0
# 554   De08100673      Denmark  2008  Developed             78.8
# 580   De64083192      Denmark  2013  Developed             81.0
# 926   Ic07919742      Iceland  2007  Developed             81.3
# 936   Ic78035961      Iceland  2005  Developed             81.0
# 1218  Lu43947910   Luxembourg  2004  Developed             78.7
# 1219  Lu64825564   Luxembourg  2008  Developed             80.0
# 1222  Lu77336160   Luxembourg  2013  Developed             81.4
# 1223  Lu83817666   Luxembourg  2011  Developed             88.0
# 1466  Ne63645744  Netherlands  2008  Developed             83.0
# ...

# %%
data.percentage_expenditure[(data.percentage_expenditure > 0.75 * pe)] = 0.75 * pe
# Out:
# /var/folders/qs/qdbfrx3j5vg02bq77wgvz3f80000gn/T/ipykernel_3932/1810445037.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data.percentage_expenditure[(data.percentage_expenditure > 0.75 * pe)] = 0.75 * pe
# ...

# %%
data.percentage_expenditure.describe()
# Out:
# count    2350.000000
# mean      649.583468
# std      1539.318386
# min         0.000000
# 25%         5.491010
# 50%        65.611455
# 75%       441.534144
# max      7692.406802
# Name: percentage_expenditure, dtype: float64

# %%
data.infant_deaths.describe()
# Out:
# count    2350.000000
# mean       28.793191
# std       111.836006
# min         0.000000
# 25%         0.000000
# 50%         3.000000
# 75%        20.750000
# max      1800.000000
# Name: infant_deaths, dtype: float64

# %%
np.percentile(data.infant_deaths, [99])[0]
# Out:
# 490.0

# %%
id = np.percentile(data.infant_deaths, [99])[0]

# %%
data[(data.infant_deaths > id)]
# Out:
#               ID  Country  Year      Status  Life_expectancy  Adult_Mortality  \
# 942   In04324722    India  2004  Developing             64.0            214.0
# 944   In09816447    India  2011  Developing             66.8            193.0
# 946   In23258207    India  2002  Developing             63.3            219.0
# 947   In29166267    India  2000  Developing             62.5            224.0
# 948   In29844654    India  2010  Developing             66.4            196.0
# 950   In38201863    India  2003  Developing             63.7            216.0
# 952   In43970523    India  2015  Developing             68.3            181.0
# 954   In46387437    India  2014  Developing             68.0            184.0
# 955   In54901558    India  2013  Developing             67.6            187.0
# 956   In66506394    India  2007  Developing             65.2             26.0
# 959   In77099325    India  2012  Developing             67.3             19.0
# ...

# %%
data.infant_deaths[(data.infant_deaths > 0.72 * id)] = 0.72 * id
# Out:
# /var/folders/qs/qdbfrx3j5vg02bq77wgvz3f80000gn/T/ipykernel_3932/3467769690.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data.infant_deaths[(data.infant_deaths > 0.72 * id)] = 0.72 * id
# ...

# %%
data.infant_deaths.describe()
# Out:
# count    2350.000000
# mean       22.677106
# std        55.690723
# min         0.000000
# 25%         0.000000
# 50%         3.000000
# 75%        20.750000
# max       352.800000
# Name: infant_deaths, dtype: float64

# %%
data.describe()
# Out:
#               Year  Life_expectancy  Adult_Mortality  infant_deaths  \
# count  2350.000000      2350.000000      2350.000000    2350.000000
# mean   2007.537447        69.275404       165.824082      22.677106
# std       4.611986         9.573065       125.060094      55.690723
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2004.000000        63.300000        74.000000       0.000000
# 50%    2008.000000        72.200000       144.000000       3.000000
# 75%    2012.000000        75.700000       227.000000      20.750000
# max    2015.000000        89.000000       723.000000     352.800000
#
#            Alcohol  percentage_expenditure  Hepatitis_B       Measles  \
# count  2350.000000             2350.000000  2350.000000   2350.000000
# mean      4.593271              649.583468    81.141811   1579.726290
# std       3.896770             1539.318386    22.381998   5172.399161
# min       0.010000                0.000000     1.000000      0.000000
# ...

# %%
data.head()
# Out:
#            ID      Country  Year      Status  Life_expectancy  \
# 0  Af04604195  Afghanistan  2013  Developing             59.9
# 1  Af04794049  Afghanistan  2000  Developing             54.8
# 2  Af07527693  Afghanistan  2006  Developing             57.3
# 3  Af11267444  Afghanistan  2010  Developing             58.8
# 4  Af12688448  Afghanistan  2005  Developing             57.3
#
#    Adult_Mortality  infant_deaths  Alcohol  percentage_expenditure  \
# 0            268.0           66.0     0.01               73.219243
# 1            321.0           88.0     0.01               10.424960
# 2            295.0           84.0     0.03               17.171518
# 3            279.0           74.0     0.01               79.679367
# 4            291.0           85.0     0.02                1.388648
#
#    Hepatitis_B  ...  Polio  Total_expenditure  Diphtheria  HIV_AIDS  \
# 0         64.0  ...   62.0               8.13        64.0       0.1
# ...

# %% [markdown]
# Dropping columns that aren't needed

# %%
data = data.drop('thinness_1-19_years', axis = 1)
data = data.drop('thinness_5-9_years', axis = 1)
data = data.drop('ID', axis = 1)
data = data.drop('Schooling', axis = 1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 19 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2350 non-null   object
#  1   Year                             2350 non-null   int64
#  2   Status                           2350 non-null   object
#  3   Life_expectancy                  2350 non-null   float64
#  4   Adult_Mortality                  2350 non-null   float64
#  5   infant_deaths                    2350 non-null   float64
#  6   Alcohol                          2350 non-null   float64
#  7   percentage_expenditure           2350 non-null   float64
#  8   Hepatitis_B                      2350 non-null   float64
#  9   Measles                          2350 non-null   float64
#  10  BMI                              2350 non-null   float64
# ...

# %% [markdown]
# Encoding using Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder 
encoder = LabelEncoder()

# %%
data['Country_Encoded'] = encoder.fit_transform(data['Country'])
data['Status_Encoded'] = encoder.fit_transform(data['Status'])

# %% [markdown]
# Dropping the columns that are objects and leaving the encoded versions

# %%
data = data.drop(['Country','Status', 'infant_deaths', 'Adult_Mortality', 'GDP', 'Alcohol', 'percentage_expenditure'], axis = 1)

# %% [markdown]
# Plotting a Heat Map to view the correlation between each column against the other

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (15,15))
# calculate the correlations:
corr = data.corr()
# Plot the correlation matrix as a heatmap
sns.heatmap(corr, annot=True, cmap='Blues', center=0, square=True)
# show heatmap:
plt.title("Heatmap for Life Expectancy")
plt.show()

# %% [markdown]
# Training the data using different models

# %%
x = data.drop("Life_expectancy", axis=1)
y = data['Life_expectancy']

# %% [markdown]
# Using the Train-Test Split Model

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (1880, 13)

# %%
x_test.shape
# Out:
# (470, 13)

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_train)

# %%
from sklearn.metrics import r2_score
lr_train = r2_score(y_train, y_pred)

# %%
y_test_pred = lr.predict(x_test)

# %% [markdown]
# Importing metric systems to calibrate accuracy

# %%
lr_test = r2_score(y_test, y_test_pred)

# %%
from sklearn.metrics import mean_squared_error
train_mse = mean_squared_error(y_train, y_pred)
print(f'MSE Train Accuracy: {train_mse}')

test_mse = mean_squared_error(y_test, y_test_pred)
print(f'MSE Test Accuracy: {test_mse}')
# Out:
# MSE Train Accuracy: 23.09319774286277
# MSE Test Accuracy: 25.63254870291265

# %%
print(f'R2Score Train Accuracy: {lr_train}')
print(f'R2Score Test Accuracy: {lr_test}')
# Out:
# R2Score Train Accuracy: 0.7471908226544623
# R2Score Test Accuracy: 0.7231550180741233

# %% [markdown]
# Ridge Regression

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
from sklearn.linear_model import Ridge

ridge_reg = Ridge(alpha=1.5,) 
ridge_reg.fit(x_train, y_train)
# Out:
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.87501e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# Ridge(alpha=1.5)

# %%
y_ridge = ridge_reg.predict(x_train)
y_test_ridge = ridge_reg.predict(x_test)

# %%
ridge_train = r2_score(y_train, y_ridge)

# %%
ridge_test = r2_score(y_test,y_test_ridge)

# %%
ridge_train_mse = mean_squared_error(y_train, y_ridge)
print(f'MSE Train Accuracy: {ridge_train_mse}')

ridge_test_mse = mean_squared_error(y_test, y_test_ridge)
print(f'MSE Test Accuracy: {ridge_test_mse}')
# Out:
# MSE Train Accuracy: 23.100160249991458
# MSE Test Accuracy: 25.704150554021474

# %%
print(f'R2Score Train Accuracy: {ridge_train}')
print(f'R2Score Test Accuracy: {ridge_test}')
# Out:
# R2Score Train Accuracy: 0.7471146016945474
# R2Score Test Accuracy: 0.7223816804943988

# %% [markdown]
# Lasso Regression

# %%
from sklearn.linear_model import Lasso

lasso_reg = Lasso(alpha=0.1,)  
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.1)

# %%
y_lasso = lasso_reg.predict(x_train)
y_test_lasso = lasso_reg.predict(x_test)

# %%
lasso_train = r2_score(y_train, y_lasso)

# %%
lasso_test = r2_score(y_test,y_test_lasso)

# %%
lasso_train_mse = mean_squared_error(y_train, y_lasso)
print(f'MSE Train Accuracy: {lasso_train_mse}')

lasso_test_mse = mean_squared_error(y_test, y_test_lasso)
print(f'MSE Test Accuracy: {lasso_test_mse}')
# Out:
# MSE Train Accuracy: 23.465025622806127
# MSE Test Accuracy: 26.51436385511098

# %%
print(f'R2Score Train Accuracy: {lasso_train}')
print(f'R2Score Test Accuracy: {lasso_test}')
# Out:
# R2Score Train Accuracy: 0.7431202949826647
# R2Score Test Accuracy: 0.7136309515171144

# %% [markdown]
# Elastic Net Regression

# %%
from sklearn.linear_model import ElasticNet

elastic_net = ElasticNet(alpha=0.8, l1_ratio=1.0)
elastic_net.fit(x_train, y_train)
# Out:
# ElasticNet(alpha=0.8, l1_ratio=1.0)

# %%
y_elastic = elastic_net.predict(x_train)
y_test_elastic = elastic_net.predict(x_test)

# %%
en_train = r2_score(y_train, y_elastic)

# %%
en_test = r2_score(y_test,y_test_elastic)

# %%
en_train_mse = mean_squared_error(y_train, y_elastic)
print(f'MSE Train Accuracy: {en_train_mse}')

en_test_mse = mean_squared_error(y_test, y_test_elastic)
print(f'MSE Test Accuracy: {en_test_mse}')
# Out:
# MSE Train Accuracy: 34.49100761641524
# MSE Test Accuracy: 39.90851533818441

# %%
print(f'R2Score Train Accuracy: {en_train}')
print(f'R2Score Test Accuracy: {en_test}')
# Out:
# R2Score Train Accuracy: 0.6224150783093899
# R2Score Test Accuracy: 0.568967084173226

# %% [markdown]
# Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor()
tree_reg.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_tree_reg =tree_reg.predict(x_train)
y_test_tree =tree_reg.predict(x_test)

# %%
dtr_train = r2_score(y_train, y_tree_reg)

# %%
dtr_test = r2_score(y_test, y_test_tree)

# %%
dtr_train_mse = mean_squared_error(y_train, y_tree_reg)
print(f'MSE Train Accuracy: {dtr_train_mse}')

dtr_test_mse = mean_squared_error(y_test, y_test_tree)
print(f'MSE Test Accuracy: {dtr_test_mse}')
# Out:
# MSE Train Accuracy: 0.0
# MSE Test Accuracy: 12.501617021276596

# %%
print(f'R2Score Train Accuracy: {dtr_train}')
print(f'R2Score Test Accuracy: {dtr_test}')
# Out:
# R2Score Train Accuracy: 1.0
# R2Score Test Accuracy: 0.8649759733839393

# %% [markdown]
# Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor(n_estimators=550 ,max_depth=None, random_state=100)

# %%
rfr.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=550, random_state=100)

# %%
y_rfr =rfr.predict(x_train)
y_test_rfr =rfr.predict(x_test)

# %%
rfr_train = r2_score(y_train, y_rfr)

# %%
rfr_test = r2_score(y_test, y_test_rfr)

# %%
print(f'R2Score Train Accuracy: {rfr_train}')
print(f'R2Score Test Accuracy: {rfr_test}')
# Out:
# R2Score Train Accuracy: 0.9910959125735412
# R2Score Test Accuracy: 0.9536087518333541

# %%
rfr_train_mse = mean_squared_error(y_train, y_rfr)
print(f'MSE Train Accuracy: {rfr_train_mse}')

rfr_test_mse = mean_squared_error(y_test, y_test_rfr)
print(f'MSE Test Accuracy: {rfr_test_mse}')
# Out:
# MSE Train Accuracy: 0.8263560388429787
# MSE Test Accuracy: 4.0265526491999175

# %% [markdown]
# Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

gb= GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
gb.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
y_gb =gb.predict(x_train)
y_test_gb =gb.predict(x_test)

gbr_train = r2_score(y_train, y_gb)

# %%
gbr_test = r2_score(y_test, y_test_gb)

# %%
print(f'R2Score Train Accuracy: {gbr_train}')
print(f'R2Score Test Accuracy: {gbr_test}')
# Out:
# R2Score Train Accuracy: 0.9398736049123135
# R2Score Test Accuracy: 0.9061532102659089

# %%
gbr_train_mse = mean_squared_error(y_train, y_gb)
print(f'MSE Train Accuracy: {gbr_train_mse}')

gbr_test_mse = mean_squared_error(y_test, y_test_gb)
print(f'MSE Test Accuracy: {gbr_test_mse}')
# Out:
# MSE Train Accuracy: 5.492327240271143
# MSE Test Accuracy: 8.689095217608665

# %% [markdown]
# XGBoost Regressor

# %%
import xgboost as xgb
from xgboost import XGBRegressor

# %%
xgboost = XGBRegressor(n_estimators = 100)
xgboost.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_xgboost = xgboost.predict(x_train)
y_test_xgboost = xgboost.predict(x_test)

# %%
xgb_train = r2_score(y_train, y_xgboost)

# %%
xgb_test = r2_score(y_test, y_test_xgboost)

# %%
print(f'R2Score Train Accuracy: {xgb_train}')
print(f'R2Score Test Accuracy: {xgb_test}')
# Out:
# R2Score Train Accuracy: 0.9989917427386644
# R2Score Test Accuracy: 0.9341520909333036

# %%
xgb_train_mse = mean_squared_error(y_train, y_xgboost)
print(f'MSE Train Accuracy: {xgb_train_mse}')

xgb_test_mse = mean_squared_error(y_test, y_test_xgboost)
print(f'MSE Test Accuracy: {xgb_test_mse}')
# Out:
# MSE Train Accuracy: 0.0921006292420974
# MSE Test Accuracy: 6.096732273763834

# %% [markdown]
# ADA Boost Regression

# %%
from sklearn.ensemble import AdaBoostRegressor

ada = AdaBoostRegressor(n_estimators = 150)
ada.fit(x_train, y_train)
# Out:
# AdaBoostRegressor(n_estimators=150)

# %%
y_ada = ada.predict(x_train)
y_test_ada = ada.predict(x_test)

# %%
ada_train = r2_score(y_train, y_ada)

# %%
ada_test = r2_score(y_test, y_test_ada)

# %%
print(f'R2Score Train Accuracy: {ada_train}')
print(f'R2Score Test Accuracy: {ada_test}')
# Out:
# R2Score Train Accuracy: 0.8790098335408686
# R2Score Test Accuracy: 0.8591954689298394

# %%
ada_train_mse = mean_squared_error(y_train, y_ada)
print(f'MSE Train Accuracy: {ada_train_mse}')

ada_test_mse = mean_squared_error(y_test, y_test_ada)
print(f'MSE Test Accuracy: {ada_test_mse}')
# Out:
# MSE Train Accuracy: 11.052011118899049
# MSE Test Accuracy: 13.036822900452648

# %% [markdown]
# Bagging Regression

# %%
from sklearn.ensemble import BaggingRegressor

bagging = BaggingRegressor(n_estimators = 210)
bagging.fit(x_train, y_train)
# Out:
# BaggingRegressor(n_estimators=210)

# %%
y_bagging = bagging.predict(x_train)
y_test_bagging = bagging.predict(x_test)

# %%
bagging_train = r2_score(y_train, y_bagging)

# %%
bagging_test = r2_score(y_test, y_test_bagging)

# %%
print(f'R2Score Train Accuracy: {bagging_train}')
print(f'R2Score Test Accuracy: {bagging_test}')
# Out:
# R2Score Train Accuracy: 0.9918118892586162
# R2Score Test Accuracy: 0.9277217862876799

# %%
bagging_train_mse = mean_squared_error(y_train, y_bagging)
print(f'MSE Train Accuracy: {bagging_train_mse}')

bagging_test_mse = mean_squared_error(y_test, y_test_bagging)
print(f'MSE Test Accuracy: {bagging_test_mse}')
# Out:
# MSE Train Accuracy: 0.7479540991219155
# MSE Test Accuracy: 6.692101912963755

# %%
from sklearn.feature_selection import SelectKBest, f_regression, RFE

select_k_best = SelectKBest(score_func=f_regression, k=10)  # select top 10 features
x_train_k_best = select_k_best.fit_transform(x_train, y_train)
x_test_k_best = select_k_best.transform(x_test)

# Fit and evaluate the model with selected features
lr.fit(x_train_k_best, y_train)
y_test_pred = lr.predict(x_test_k_best)
mse_k_best = mean_squared_error(y_test, y_test_pred)
print(f'MSE with SelectKBest: {mse_k_best}')

# Recursive Feature Elimination (RFE)
rfe = RFE(estimator=LinearRegression(), n_features_to_select=10)
x_train_rfe = rfe.fit_transform(x_train, y_train)
x_test_rfe = rfe.transform(x_test)

# Fit and evaluate the model with RFE selected features
lr.fit(x_train_rfe, y_train)
y_test_pred = lr.predict(x_test_rfe)
mse_rfe = mean_squared_error(y_test, y_test_pred)
print(f'MSE with RFE: {mse_rfe}')
# Out:
# MSE with SelectKBest: 25.848862393795788
# MSE with RFE: 25.749698586694226

# %%
from sklearn.model_selection import cross_val_score

# %%
# Perform 5-fold cross-validation
cv_scores = cross_val_score(lr, x, y, cv=5, scoring='neg_mean_squared_error')

# Convert negative MSE to positive for better interpretation
mse_scores = -cv_scores

print(f'Cross-Validation MSE Scores: {mse_scores}')
print(f'Average MSE: {mse_scores.mean()}')
# Out:
# Cross-Validation MSE Scores: [26.65813262 25.6073313  21.60604473 28.76668739 28.42840027]
# Average MSE: 26.213319263600546
